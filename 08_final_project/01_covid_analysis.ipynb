# %% [markdown]
# ## Итоговая практическая работа: Анализ пандемии COVID-19
#
#
# ### Важно!
# Каждый студент получает для анализа **свою страну**. Название вашей страны: **`{COUNTRY_NAME}`** (преподаватель сообщит индивидуально).
#
# ### Описание данных
# Датасет [`worldometer_coronavirus_daily_data.csv`](https://www.kaggle.com/datasets/josephassaker/covid19-global-dataset?resource=download) содержит ежедневную статистику по странам мира:
# - `date` — дата
# - `country` — страна
# - `cumulative_total_cases` — общее количество случаев на текущую дату (накопленным итогом)
# - `daily_new_cases` — новые случаи за день
# - `active_cases` — текущие активные случаи (болеют сейчас)
# - `cumulative_total_deaths` — общее количество смертей на текущую дату
# - `daily_new_deaths` — новые смерти за день
#
# ### Задания
#
# ---

# %% [markdown]
# #### Часть 1. Служебный класс для работы с датасетом
# Создайте класс `CovidDataAnalyzer`, который:
# - В конструкторе (`__init__`) принимает путь к CSV-файлу и загружает данные в `self.df`.
# - Приводит колонку `date` к типу `datetime`.
# - Автоматически создает атрибут `self.countries` — список уникальных стран.
# - Принимает опциональный параметр `country_name` (если передан, сразу сохраняет данные для этой страны в `self.country_df`).
#
# **Методы класса:**
# 1.  `get_country_data(self, country_name)` — возвращает DataFrame для указанной страны.
# 2.  `save_state(self, filename)` — сохраняет текущее состояние `self.df` в CSV.
# 3.  `basic_info(self)` — выводит информацию о датасете (`.info()`, `.describe()`, количество пропусков).
# 4.  `fill_missing(self, method='ffill')` — заполняет пропуски в числовых колонках методом `'ffill'` (forward fill) или `'bfill'`.
# 5.  `add_ratio_column(self)` — создает новый столбец `'death_rate'` = (`cumulative_total_deaths` / `cumulative_total_cases`) * 100.
#
# **Напишите реализацию класса здесь:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class CovidDataAnalyzer:
    def __init__(self, file_path, country_name=None):
        # TODO: загрузить данные, привести date к datetime
        # TODO: создать self.countries
        # TODO: если country_name передан, сохранить данные для этой страны в self.country_df
        pass
    
    def get_country_data(self, country_name):
        # TODO: вернуть DataFrame для страны
        pass
    
    def save_state(self, filename):
        # TODO: сохранить self.df в CSV
        pass
    
    def basic_info(self):
        # TODO: вывести информацию о датасете
        pass
    
    def fill_missing(self, method='ffill'):
        # TODO: заполнить пропуски в числовых колонках
        pass
    
    def add_ratio_column(self):
        # TODO: добавить колонку death_rate
        pass

# %%
# Инициализация класса с вашей страной
# analyzer = CovidDataAnalyzer('worldometer_coronavirus_daily_data.csv', country_name='Russia')
# analyzer.basic_info()

# %% [markdown]
# #### Часть 2. Полноценный анализ при помощи pandas
#
# **Сначала выполните анализ для ВСЕГО датасета:**
#
# 1.  Выведите количество уникальных стран в датасете.
# 2.  Найдите **топ-5 стран** по максимальному значению `cumulative_total_cases` (общее число заболевших за всю историю).
# 3.  Сгруппируйте данные по странам и рассчитайте для каждой **суммарное количество новых случаев** (`daily_new_cases`). Выведите топ-3 стран.
# 4.  Найдите **день с максимальным количеством новых случаев в мире** (суммарно по всем странам).
#
# **Затем выполните анализ для ВАШЕЙ СТРАНЫ:**
#
# 5.  Рассчитайте **коэффициент летальности** для вашей страны (`cumulative_total_deaths` / `cumulative_total_cases`) на последнюю доступную дату.
# 6.  Найдите **день с максимальным количеством новых смертей** в вашей стране.
# 7.  Определите, в каком **месяце** был зафиксирован пик новых случаев в вашей стране.

# %%
# АНАЛИЗ ВСЕГО ДАТАСЕТА

# 1. Количество уникальных стран

# 2. Топ-5 стран по cumulative_total_cases

# 3. Суммарные новые случаи по странам (топ-3)

# 4. День с максимальным числом новых случаев в мире


# АНАЛИЗ ВАШЕЙ СТРАНЫ

# 5. Коэффициент летальности на последнюю дату

# 6. День с максимальным количеством новых смертей

# 7. Месяц с пиком новых случаев

# %% [markdown]
# #### Часть 3. Data Engineering: обогащение данных
#
# Выполните следующие преобразования:
#
# 1.  **Создайте категориальный признак на основе временного ряда**
#
#     Проанализируйте распределение `daily_new_cases` для вашей страны. Используя визуализацию (гистограмму или boxplot), **самостоятельно определите границы** для категорий:
#     - `'low'` — низкий уровень заболеваемости
#     - `'high'` — высокий уровень
#     - `'outbreak'` — вспышка (экстремально высокие значения)
#
#     Напишите функцию `classify_cases`, которая на основе ваших границ присваивает категорию, и примените её к колонке `daily_new_cases`. Результат сохраните в колонку `'cases_level'`.
#
#     **Обоснуйте** в комментариях, почему вы выбрали именно такие границы.
#
# 2.  **Выделите компоненты времени**
#
#     Из колонки `date` выделите в отдельные колонки:
#     - `'year'` — год
#     - `'month'` — месяц
#     - `'day_of_week'` — день недели (0=понедельник, 6=воскресенье)
#
# 3.  **Агрегация по дням недели**
#
#     Рассчитайте среднее количество `daily_new_cases` для каждого дня недели. Какой день недели в среднем самый «тяжелый» по заболеваемости? Есть ли «эффект выходного дня»?

# %%
# 1. Анализ распределения daily_new_cases и создание категорий

# Визуализация для определения границ

# Определение функции классификации (укажите свои границы)
def classify_cases(value):
    # TODO: определить границы на основе анализа распределения
    pass

# Применение функции


# 2. Выделение компонентов времени


# 3. Агрегация по дням недели

# %% [markdown]
# #### Часть 4. Визуализация с помощью Matplotlib и Seaborn
#
# Постройте следующие графики, обязательно подписывайте оси и заголовки:
#
# 1.  **Временной ряд (line plot)**: Для вашей страны на графиках покажите динамику `daily_new_cases` и `daily_new_deaths`.
# 2.  **Хитмэп корреляций (heatmap)**: Постройте корреляционную матрицу для всех числовых колонок вашей страны.
# 3.  **Гистограмма**: Покажите распределение `daily_new_cases` по созданным категориям `cases_level`.
# 4.  **Скаттерплот**: Покажите зависимость `daily_new_cases` от `daily_new_deaths` по созданным категориям `cases_level`.
# 5.  **Гистограмма (histplot)**: Распределение `death_rate` среди ВСЕХ стран мира.
# 6.  **Столбчатая диаграмма**: Среднее количество `daily_new_cases` по дням недели (результат из part 3).
#
# **Требования к графикам:**
# - Использовать `plt.style.use('seaborn-v0_8-whitegrid')`
# - Настройка русского текста (передана ниже)
# - Везде должны быть заголовки и подписи осей

# %%
# Настройка стиля (выполните эту ячейку перед построением графиков)
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('Set2')

# Настройка отображения русского текста (если нужно)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial', 'DejaVu Sans', 'Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
# 1. Временной ряд для вашей страны

# 2. Heatmap корреляций

# 3. Boxplot по категориям заболеваемости

# 4. Гистограмма смертности (все страны)

# 5. Среднее по дням недели

# %% [markdown]
# #### Часть 5. Выводы по анализу
#
# Сформулируйте **5 содержательных выводов** на основе полученных результатов. Выводы должны отражать как глобальную картину, так и специфику вашей страны.
#
# **Вывод 1 (глобальный):**
#
# **Вывод 2 (ваша страна):**
#
# **Вывод 3 (временные закономерности):**
#
# **Вывод 4 (корреляции):**
#
# **Вывод 5 (общий):**

# %%
print("Работа завершена")
