# %% [markdown]
# ## Самостоятельная практика: анализ данных пассажиров Титаника
#
# **Данные:** 891 пассажир
#
# **Колонки:**
# - `survived` — выжил (1) / погиб (0)
# - `pclass` — класс билета (1, 2, 3)
# - `name` — имя пассажира
# - `sex` — пол (male / female)
# - `age` — возраст
# - `sibsp` — количество братьев/сестёр/супругов на борту
# - `parch` — количество родителей/детей на борту
# - `fare` — стоимость билета в фунтах
# - `embarked` — порт посадки (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# **Задание:** Ответьте на вопросы, используя Pandas, Matplotlib и Seaborn. В конце сделайте выводы.

# %% [markdown]
# ## Часть 1. Загрузка и первичный осмотр (5 минут)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Настройка стиля
plt.style.use('seaborn-v0_8-whitegrid')

# %%
# Настройка отображения русского текста

# %%
# Загружаем данные
titanic = sns.load_dataset('titanic')

print(f"Загружено строк: {len(titanic)}")
titanic.head()

# %%
# Задание 1.1: Выведите информацию о датафрейме (типы данных, пропуски)

# %%
# Задание 1.2: Сколько мужчин и женщин было на борту?

# %% [markdown]
# ## Часть 2. Гистограммы (15 минут)

# %%
# Задание 2.1: Постройте гистограмму распределения возраста пассажиров
# Добавьте линии медианы и среднего
# Подсказка: заполните пропуски в возрасте медианой

# %%
# Задание 2.2: Постройте гистограмму распределения возраста с разделением по полу
# Используйте hue='sex'

# %% [markdown]
# ## Часть 3. Круговая диаграмма (10 минут)

# %%
# Задание 3.1: Посчитайте количество выживших и погибших
# Постройте круговую диаграмму с процентами

# %% [markdown]
# ## Часть 4. Столбчатые диаграммы (15 минут)

# %%
# Задание 4.1: Постройте столбчатую диаграмму выживаемости по полу

# %%
# Задание 4.2: Постройте столбчатую диаграмму выживаемости по классу (pclass)

# %% [markdown]
# ## Часть 5. Диаграмма рассеяния (10 минут)

# %%
# Задание 5.1: Постройте диаграмму рассеяния: возраст vs стоимость билета
# Раскрасьте точки по полу

# %% [markdown]
# ## Часть 6. Тепловая карта корреляции (10 минут)

# %%
# Задание 6.1: Постройте тепловую карту корреляции для числовых признаков
# Выберите только числовые колонки

# %% [markdown]
# ## Часть 7. Матрица диаграмм рассеяния (pairplot) (10 минут)

# %%
# Задание 7.1: Постройте pairplot для числовых признаков
# Используйте vars=['age', 'fare', 'pclass'] и hue='survived'

# %% [markdown]
# ## Часть 8. Ваши выводы (10 минут)
#
# Напишите 5-7 предложений с выводами по анализу
#
# **Ваши выводы:**
#
# ...
