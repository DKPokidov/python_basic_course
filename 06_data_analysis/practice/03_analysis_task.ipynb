# %% [markdown]
# # Практическая работа: Анализ данных о школьных зданиях
# ## Pandas — группировка, фильтрация, агрегация, визуализация
#
# **Цель работы:** Научиться анализировать данные о школьных зданиях, используя библиотеку Pandas.
#
# **Данные:** Датафрейм `schools.json` содержит информацию о 964 школьных зданиях.
#
# **Структура данных:**
# | Колонка | Тип | Описание |
# |---------|-----|----------|
# | `building_area` | float64 | Площадь здания (кв. м) |
# | `is_living` | bool | Используется ли здание как жилое |
# | `adress` | object | Адрес здания |
# | `object_name` | object | Название объекта |
# | `capacity` | int64 | Вместимость (количество учеников) |
#
# ---

# %% [markdown]
# ## Часть 1. Подготовка
#
# Импортируйте библиотеки и загрузите данные.

# %% [markdown]
# ## Часть 2. Первичный анализ данных

# %% [markdown]
# ### Задание 2.1
# Сколько всего зданий в датасете? Сколько уникальных адресов?

# %%
# Ваш код

# %% [markdown]
# ### Задание 2.2
# Выведите основную статистику по числовым колонкам (`building_area`, `capacity`). Какие значения вы видите?

# %%
# Ваш код

# %% [markdown]
# ### Задание 2.3
# Проверьте, есть ли в данных пропуски. В каких колонках?

# %%
# Ваш код

# %% [markdown]
# ### Задание 2.4
# Сколько зданий используется как жилые (`is_living == True`)? А сколько как нежилые?

# %%
# Ваш код

# %% [markdown]
# ## Часть 3. Фильтрация данных

# %% [markdown]
# ### Задание 3.1
# Отфильтруйте данные:
# - Только нежилые здания (`is_living == False`)
# - Площадь больше 1000 кв.м
#
# Сколько таких зданий? Выведите первые 5.

# %%
# Ваш код

# %% [markdown]
# ### Задание 3.2
# Найдите здания с вместительностью больше 500 учеников, но площадью меньше 2000 кв.м. Выведите их названия и адреса.

# %%
# Ваш код

# %% [markdown]
# ### Задание 3.3
# Найдите 10 самых вместительных зданий (по `capacity`). Выведите название, адрес и вместительность.

# %%
# Ваш код

# %% [markdown]
# ## Часть 4. Группировка и агрегация

# %% [markdown]
# ### Задание 4.1
# Сгруппируйте данные по признаку `is_living`. Для каждой группы посчитайте:
# - Количество зданий
# - Среднюю площадь
# - Среднюю вместительность
# - Общую вместительность

# %%
# Ваш код

# %% [markdown]
# ### Задание 4.2
# Создайте новую колонку `density` — плотность учеников на 1 кв.м (вместительность / площадь).
#
# Затем найдите среднюю плотность для жилых и нежилых зданий.

# %%
# Ваш код

# %% [markdown]
# ### Задание 4.3
# Сгруппируйте данные по первым 3 символам адреса (улице).
#
# Подсказка: `df['adress'].str[:3]`
#
# Посчитайте количество зданий на каждой улице и выведите топ-5.

# %%
# Ваш код

# %% [markdown]
# ### Задание 4.4
# Для каждой группы по `is_living` найдите:
# - Максимальную площадь
# - Минимальную вместительность
# - Суммарную вместительность
# - Количество зданий
#
# Переименуйте колонки результата на русский язык.

# %%
# Ваш код

# %% [markdown]
# ## Часть 5. Сортировка и поиск

# %% [markdown]
# ### Задание 5.1
# Найдите топ-5 зданий с самой высокой плотностью учеников (`density`). Выведите название, адрес, площадь, вместительность и плотность.

# %%
# Ваш код

# %% [markdown]
# ### Задание 5.2
# Найдите здания, у которых вместительность больше средней вместительности по всему датасету. Сколько таких зданий?

# %%
# Ваш код

# %% [markdown]
# ### Задание 5.3
# Отсортируйте данные по площади по убыванию и выведите первые 10 зданий. Какое здание самое большое по площади?

# %%
# Ваш код

# %% [markdown]
# ## Часть 6. Анализ текстовых данных

# %% [markdown]
# ### Задание 6.1
# Извлеките номер здания из адреса (если он есть). Подсказка: используйте регулярное выражение или поиск по строке.

# %%
# Ваш код

# %% [markdown]
# ### Задание 6.2
# Посчитайте, сколько зданий находится на улицах, начинающихся на "ул" (улица), "пр" (проспект), "пер" (переулок).

# %%
# Ваш код

# %% [markdown]
# ## Часть 7. Продвинутые методы анализа

# %% [markdown]
# ### Задание 7.1
# Создайте колонку `size_category`:
# - `small` — площадь < 500 кв.м
# - `medium` — площадь от 500 до 1500 кв.м
# - `large` — площадь > 1500 кв.м
#
# Посчитайте количество зданий в каждой категории.

# %%
# Ваш код

# %% [markdown]
# ### Задание 7.2
# Для каждой категории размера посчитайте среднюю вместительность и среднюю плотность.

# %%
# Ваш код

# %% [markdown]
# ### Задание 7.3
# Создайте сводную таблицу, показывающую среднюю вместительность для жилых и нежилых зданий в каждой категории размера.

# %%
# Ваш код

# %% [markdown]
# ## Часть 8. Блиц
#
# Ответьте на вопросы, используя код.
#
# ### 🔍 Вопрос 1
# **Как распределены здания по типу использования (жилые/нежилые) в процентном соотношении?**

# %%
# Ваш код

# %% [markdown]
# ### 🔍 Вопрос 2
# **Есть ли связь между площадью здания и его вместительностью? (Сравните среднюю вместительность для зданий больше и меньше 1500 кв.м)**

# %%
# Ваш код

# %% [markdown]
# ### 🔍 Вопрос 3
# **Какая улица (первые 3 символа адреса) лидирует по суммарной вместительности всех зданий?**

# %%
# Ваш код

# %% [markdown]
# ### 🔍 Вопрос 4
# **Сколько зданий имеют вместительность меньше 100 учеников? Какой процент от общего числа?**

# %%
# Ваш код

# %% [markdown]
# ### 🔍 Вопрос 5
# **Какой тип зданий (жилые/нежилые) в среднем имеет большую плотность учеников?**

# %%
# Ваш код

# %% [markdown]
# ## Часть 9. Итоговый проект (аналитическая задача)

# %% [markdown]
# ### Задача: Определение приоритетов для ремонта
#
# Представьте, что вы аналитик в городском департаменте образования. Вам нужно определить **10 зданий, которые требуют первоочередного внимания**.
#
# **Критерии для приоритизации:**
# 1. Здание не является жилым (`is_living == False`)
# 2. Высокая плотность учеников (`density` выше среднего)
# 3. Небольшая площадь (чем меньше площадь, тем сложнее разместить всех учеников)
#
# **Задание:**
# - Отфильтруйте нежилые здания
# - Оставьте только те, у которых плотность выше средней
# - Отсортируйте по площади (от самых маленьких к самым большим)
# - Выведите топ-10 таких зданий с колонками: `object_name`, `adress`, `building_area`, `capacity`, `density`

# %%
# Ваш код
