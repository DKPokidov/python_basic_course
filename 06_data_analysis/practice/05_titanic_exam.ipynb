# %% [markdown]
# # Зачётная работа: Анализ данных пассажиров Титаника
#
# Данные: 887 пассажиров
#
# Колонки:
# - Survived — выжил 1 / погиб 0
# - Pclass — класс билета 1 2 3
# - Name — имя пассажира
# - Sex — пол male / female
# - Age — возраст
# - Siblings — братья/сёстры/супруги на борту
# - Parents — родители/дети на борту
# - Fare — стоимость билета в фунтах
#
# Задание: Ответьте на вопросы, используя Pandas. В конце сделайте выводы.

# %% [markdown]
# ## Часть 1. Загрузка и первичный осмотр

# %%
# Импортируйте необходимые библиотеки и подключите датасет
import pandas as pd

# %%
# Задание 1.1: Информация о датафрейме
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
# Задание 1.1: Выведите информацию о датафрейме

# %%
# Задание 1.2: Сколько мужчин и женщин было на борту?

# %% [markdown]
# ## Часть 2. Анализ выживаемости по группам

# %%
# Задание 2.1: Напишите функцию, которая считает процент выживших

def survival_rate(df, column, value):
    """
    Возвращает процент выживших среди пассажиров,
    у которых колонка column равна value
    """
    pass

# Проверьте:
# print(survival_rate(df, 'Sex', 'female'))
# print(survival_rate(df, 'Pclass', 1))

# %%
# Задание 2.2: Процент выживших для каждой комбинации пола и класса

# %%
# Задание 2.3: Сравните выживаемость детей Age <= 16 и взрослых

# %% [markdown]
# ## Часть 3. Анализ стоимости билетов

# %%
# Задание 3.1: Средняя, минимальная и максимальная стоимость по классам

# %%
# Задание 3.2: Сравните стоимость билета у выживших и погибших

# %% [markdown]
# ## Часть 4. Неочевидные закономерности

# %%
# Задание 4.1: Создайте колонку FamilySize = Siblings + Parents
# Посчитайте выживаемость для каждого размера семьи

# %%
# Задание 4.2: Найдите топ-10 самых дорогих билетов среди выживших

# %% [markdown]
# ## Часть 5. Ваши выводы
#
# Напишите 5-7 предложений с выводами по анализу:
#
# 1. Кто выживал чаще — мужчины или женщины?
# 2. Влиял ли класс на шансы выжить?
# 3. Дети выживали чаще взрослых?
# 4. Была ли связь между стоимостью билета и выживанием?
# 5. Как размер семьи влиял на выживаемость?
# 6. Что ещё интересного вы заметили?
#
# ---
#
# Ваши выводы:

# %% [markdown]
# ## Бонусное задание
#
# Найдите 5 пассажиров, которые:
# - были в 3-м классе,
# - заплатили больше 50 фунтов,
# - выжили.
#
# Выведите их имена, возраст и стоимость билета.

# %%
# Ваш код здесь

# %%
# Дополнительное задание 1
# Найдите процент выживших среди пассажиров с билетом дороже 50 фунтов

# %%
#  Дополнительное задание 2
# Создайте колонку AgeGroup: child (0-16), adult (17-60), senior (60+)
# Посчитайте выживаемость по группам

# %%
# Дополнительное задание 3
# Найдите 3 самые популярные мужские и женские имена

# %%
# Дополнительное задание 4
# Какой класс был самым "дорогим"? Посчитайте медианную стоимость по классам

# %%
# Дополнительное задание 5
# Выживаемость в зависимости от количества родственников на борту (FamilySize)
